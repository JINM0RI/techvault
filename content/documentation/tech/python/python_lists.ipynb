# %% [markdown]
# # Python Lists
#
# Lists store multiple values in one variable.

# %%
numbers = [1, 2, 3]
numbers.append(4)
numbers

# %% [markdown]
# The output confirms the list now includes `4`.
